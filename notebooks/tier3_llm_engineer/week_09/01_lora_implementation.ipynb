# %% [markdown]
# # LoRA from Scratch
#
# Generated Demonstration Notebook

# %%
import torchfrom src.llm.fine_tuning import LoRALayer# 1. Create Base Layer simulating a dense layer weightin_features, out_features = 768, 768lora = LoRALayer(in_features, out_features, r=8, alpha=16)# 2. Forward Passx = torch.randn(1, in_features)output = lora(x)print(f"LoRA adapted output shape: {output.shape}")
