# %% [markdown]
# # Attention from Scratch
#
# Generated Demonstration Notebook

# %%
import torchfrom src.llm.attention import MultiHeadAttention# 1. Initialize MHAd_model = 512num_heads = 8mha = MultiHeadAttention(d_model, num_heads)# 2. Create Dummy Inputs (Batch, Seq, Dim)x = torch.randn(2, 10, d_model)# 3. Forward Passoutput, weights = mha(x, x, x)print(f"Input Shape: {x.shape}")print(f"Output Shape: {output.shape}")
