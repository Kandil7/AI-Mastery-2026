# %% [markdown]
# # Building a RAG Pipeline
#
# Generated Demonstration Notebook

# %%
from src.llm.rag import RAGPipeline, Document# 1. Setup Pipelinerag = RAGPipeline(embedding_dim=384)# 2. Index Documentsdocs = [    Document(content="The white-box approach emphasizes understanding foundations.", metadata={"source": "manifesto"}),    Document(content="Transformers use self-attention mechanisms.", metadata={"source": "lecture"})]rag.add_documents(docs)# 3. Retrievequery = "What is the white-box approach?"results = rag.retrieve(query, k=1)print(f"Retrieved: {results[0].content}")
