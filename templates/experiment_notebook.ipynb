# %% [markdown]
# # [Experiment Title]
#
# **Date**: YYYY-MM-DD
# **Author**: [Your Name]
# **Sprint**: Week X - [Focus Area]
#
# ---
#
# ## 🎯 Problem Statement
#
# **Goal**: [One sentence describing what we're building/exploring]
#
# **Why it matters**: [Business/technical motivation]
#
# **Success criteria**:
# - [ ] Criterion 1
# - [ ] Criterion 2

# %% [markdown]
# ## 📦 Setup & Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Add project root to path
import sys
sys.path.insert(0, '../..')

# Project imports
# from src.core import ...
# from src.ml import ...

# %% [markdown]
# ## 📊 Data Loading & EDA

# %%
# Load data
# data = pd.read_csv('...')
# data.head()

# %%
# Quick EDA
# data.describe()

# %% [markdown]
# ## 🔧 Implementation

# %%
# Main implementation here
pass

# %% [markdown]
# ## 📈 Evaluation & Metrics

# %%
# Evaluate results
# accuracy = ...
# print(f"Accuracy: {accuracy:.2%}")

# %% [markdown]
# ## 🎤 Interview Connection
#
# **Question this helps answer**: [e.g., "How would you design a RAG system?"]
#
# **Key talking points**:
# 1. [Technical decision made]
# 2. [Trade-off considered]
# 3. [Result achieved]

# %% [markdown]
# ## 📝 Conclusions
#
# **What worked**:
# -
#
# **What didn't work**:
# -
#
# **Next steps**:
# -
