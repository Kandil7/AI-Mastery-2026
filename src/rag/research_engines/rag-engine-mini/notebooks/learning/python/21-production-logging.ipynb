# %% [markdown]
# # Python Logging in Production
#
# ## Learning Objectives
#
# - Use log levels correctly
# - Emit structured logs
# - Include correlation IDs
# - Avoid sensitive data
#
# ---

# %% [markdown]
# ## 1. Log Levels

# %%
import logging

logger = logging.getLogger(__name__)
logger.debug('debug')
logger.info('info')
logger.warning('warning')
logger.error('error')
print('levels example')

# %% [markdown]
# ## 2. Structured Logs

# %%
logger.info('document.uploaded', extra={'doc_id': '123', 'size': 1024})
print('structured log example')

# %% [markdown]
# ## 3. Correlation IDs

# %%
request_id = 'req-123'
logger.info('request.start', extra={'request_id': request_id})
print('correlation id example')

# %% [markdown]
# ## Summary
#
# - Use levels for severity
# - Prefer structured logs
# - Avoid sensitive data
