# %% [markdown]
# # Python CLI Testing and Argument Parsing Patterns
#
# ## Learning Objectives
#
# - Structure CLI code for testability
# - Parse args into config objects
# - Keep main functions thin
#
# ---

# %% [markdown]
# ## 1. Parsing Function

# %%
import argparse
from dataclasses import dataclass

@dataclass
class Config:
    name: str

def build_parser() -> argparse.ArgumentParser:
    parser = argparse.ArgumentParser()
    parser.add_argument('name')
    return parser

def parse_args(argv: list[str]) -> Config:
    parser = build_parser()
    args = parser.parse_args(argv)
    return Config(name=args.name)

cfg = parse_args(['Alice'])
print(cfg.name)

# %% [markdown]
# ## Summary
#
# - Separate parsing from logic
# - Test parse_args directly
# - Keep main thin
