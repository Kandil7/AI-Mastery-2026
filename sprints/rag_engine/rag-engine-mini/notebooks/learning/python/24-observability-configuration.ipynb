# %% [markdown]
# # Python Configuration for Observability
#
# ## Learning Objectives
#
# - Centralize logging config
# - Enable metrics exporters
# - Use env vars for settings
#
# ---

# %% [markdown]
# ## 1. Logging Configuration

# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s %(levelname)s %(name)s - %(message)s'
)

print('logging configured')

# %% [markdown]
# ## 2. Metrics Configuration

# %%
print('start_http_server(8001)')

# %% [markdown]
# ## Summary
#
# - Centralize logging
# - Expose metrics safely
# - Use env vars to control settings
